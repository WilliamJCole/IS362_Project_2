# %% [markdown]
# ## Untidy Data Project 2
#
# ### Data Set Choices:
#
# New York City: Causes of Death
#
# University Returns
#
# Diaper Data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Causes of Death:
#
# Which cause of death had the most deaths in 2014?

# %%
death = pd.read_csv("https://raw.githubusercontent.com/WilliamJCole/Project_2/master/New_York_City_Leading_Causes_of_Death.csv")
death.sort_values("Deaths", ascending=0, kind='quicksort')
# Out:
#       Year                                      Leading Cause Sex  \
# 631   2012     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 554   2013              Malignant Neoplasms (Cancer: C00-C97)   M
# 235   2007                                   All Other Causes   M
# 16    2011          Cerebrovascular Disease (Stroke: I60-I69)   F
# 366   2007              Malignant Neoplasms (Cancer: C00-C97)   F
# 191   2009  Human Immunodeficiency Virus Disease (HIV: B20...   F
# 442   2013                        Diabetes Mellitus (E10-E14)   M
# 127   2014                                   All Other Causes   M
# 51    2014       Chronic Lower Respiratory Diseases (J40-J47)   M
# 603   2014     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 289   2010  Essential Hypertension and Renal Diseases (I10...   F
# 609   2011            Influenza (Flu) and Pneumonia (J09-J18)   M
# 524   2013              Malignant Neoplasms (Cancer: C00-C97)   F
# ...

# %% [markdown]
# ### University:

# %%
univ = pd.read_csv("https://raw.githubusercontent.com/WilliamJCole/Project_2/master/University%20returns_for_figshare_FINAL.csv")
univ.sort_values(by=["COST"], ascending=False)
# Out:
#                        PMID/PMCID  \
# 1751  PMID: 23372785 PMC3556037
# 72                        3947303
# 2118                   PMC3716626
# 958                 : PMC3711325
# 707             PMCID: PMC3557415
# 1417                          NaN
# 1750           PMCID: PMC3706538
# 692                    PMC3567503
# 941        PMCID:\r    PMC3789947
# 703                    PMC3564010
# 1747     PMCID:\r    PMC3647051\r
# 1749       PMCID:\r    PMC3737189
# 1748       PMCID:\r    PMC3720585
# 1746     PMCID:\r    PMC3767740\r
# 1745       PMCID:\r    PMC3732248
# 1744       PMCID:\r    PMC3579793
# 1743     PMCID:\r    PMC3609862\r
# 499                PMID: 23935057
# 1596                   PMC3692470
# 940             PMCID: PMC3481303
# 1742           PMCID: PMC3790696
# 898                    PMC3717731
# 1284                   PMC3518124
# 1959                          NaN
# 3                             NaN
# 185                PMCID: 3581401
# ...

# %% [markdown]
# ### Diapers:

# %%
univ = pd.read_csv("https://raw.githubusercontent.com/WilliamJCole/Project_2/master/University%20returns_for_figshare_FINAL.csv")
univ.sort_values(by=["COST"], ascending=False)
